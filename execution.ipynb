# %% [markdown]
# # Execution Notebook

# %%
import train, test

# %%
train.train()

# %%
accuracy, predicted_labels = test.test(data_test_file_path = "path/to/your/test_data.npy",
                                       labels_test_file_path = "path/to/your/test_labels.npy"
                                      )
