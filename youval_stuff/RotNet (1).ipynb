# %% [markdown]
# # Final Project - Training Data

# %% [markdown]
# This Notebook loads and displays some examples from the training dataset.
#
# The training dataset contains a total of 8443 samples. All groups have been given the same training dataset and the final report will be graded based on the performance on this training data.
#
# * You should expect the test dataset to have the same format as the training data: $270,000\times M$ ```numpy``` array, where $M$ is the number of test samples.
# * This means that *any* pre-processing applied in the training data should also be applied in the test data.

# %% [markdown]
# ---

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.preprocessing.image import Iterator
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Flatten, Convolution2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from utils import RotNetDataGenerator, crop_largest_rectangle, angle_error, rotate, binarize_images, display_examples
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard
import numpy as np
from skimage.transform import resize
import pickle
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelBinarizer

# %%
train_df=pd.read_csv('sign_mnist_train.csv')
test_df=pd.read_csv('sign_mnist_test.csv')

# %%
train_label=train_df['label']
train_label.head()
trainset=train_df.drop(['label'],axis=1)

# %%
X_train = trainset.values
X_train = trainset.values.reshape(-1,28,28,1)
print(X_train.shape)
# Out:
# (27455, 28, 28, 1)

# %%
test_label=test_df['label']
X_test=test_df.drop(['label'],axis=1)
print(X_test.shape)
# Out:
# (7172, 784)

# %%
lb=LabelBinarizer()
y_train=lb.fit_transform(train_label)
y_test=lb.transform(test_label)

# %%
X_test=X_test.values.reshape(-1,28,28,1)

# %%
X_train = np.squeeze(X_train, axis=-1)
X_test = np.squeeze(X_test, axis=-1)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (27455, 28, 28) (27455, 24) (7172, 28, 28) (7172, 24)

# %%
# number of convolutional filters to use
nb_filters = 64
# size of pooling area for max pooling
pool_size = (2, 2)
# convolution kernel size
kernel_size = (3, 3)

nb_train_samples, img_rows, img_cols = X_train.shape
img_channels = 1
input_shape = (img_rows, img_cols, img_channels)
nb_test_samples = X_test.shape[0]
nb_classes = 360

# model definition
input = Input(shape=(img_rows, img_cols, img_channels))
x = Convolution2D(nb_filters, kernel_size[0], kernel_size[1],
                  activation='relu')(input)
x = Convolution2D(nb_filters, kernel_size[0], kernel_size[1],
                  activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(nb_classes, activation='softmax')(x)

model = Model(inputs=input, outputs=x)
# Out:
# 2023-11-27 10:45:57.251253: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 10:45:59.956789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78911 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:07:00.0, compute capability: 8.0
# 2023-11-27 10:45:59.961637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 78911 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:4e:00.0, compute capability: 8.0

# %%
# model compilation
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=[angle_error, 'accuracy'])

# %%
# training parameters
batch_size = 128
nb_epoch = 50
output_filename = "rotnet"

# callbacks
checkpointer = ModelCheckpoint(
    filepath=output_filename,
    save_best_only=True
)
early_stopping = EarlyStopping(patience=2)
tensorboard = TensorBoard()

# training loop
history = model.fit(
    RotNetDataGenerator(X_train, preprocess_func=binarize_images),
    steps_per_epoch=nb_train_samples // batch_size,  # Adjust this based on your dataset size
    epochs=nb_epoch,
    validation_data=RotNetDataGenerator(X_test, preprocess_func=binarize_images),
    validation_steps=nb_test_samples // batch_size,  # Adjust this based on your dataset size
    verbose=1,
    callbacks=[checkpointer, early_stopping, tensorboard]
)
# Out:
# Epoch 1/50
# 2023-11-27 10:46:12.699218: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
# 2023-11-27 10:46:17.517366: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 209/214 [============================>.] - ETA: 0s - loss: 5.3791 - angle_error: 82.8720 - accuracy: 0.0159
# 2023-11-27 10:46:21.757314: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 11s 15ms/step - loss: 5.3514 - angle_error: 82.3408 - accuracy: 0.0175 - val_loss: 3.7918 - val_angle_error: 48.2732 - val_accuracy: 0.0809
# Epoch 2/50
# 213/214 [============================>.] - ETA: 0s - loss: 3.5009 - angle_error: 45.9682 - accuracy: 0.1029INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 3.4990 - angle_error: 45.9243 - accuracy: 0.1027 - val_loss: 2.5184 - val_angle_error: 18.0335 - val_accuracy: 0.2575
# Epoch 3/50
# 213/214 [============================>.] - ETA: 0s - loss: 2.7659 - angle_error: 26.0336 - accuracy: 0.1942INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 2.7649 - angle_error: 26.0536 - accuracy: 0.1943 - val_loss: 1.9837 - val_angle_error: 7.9408 - val_accuracy: 0.3761
# Epoch 4/50
# 214/214 [==============================] - ETA: 0s - loss: 2.4025 - angle_error: 18.6042 - accuracy: 0.2501INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 2.4025 - angle_error: 18.6042 - accuracy: 0.2501 - val_loss: 1.7393 - val_angle_error: 6.7073 - val_accuracy: 0.4043
# Epoch 5/50
# 211/214 [============================>.] - ETA: 0s - loss: 2.2115 - angle_error: 16.9191 - accuracy: 0.2858INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 2.2089 - angle_error: 16.8753 - accuracy: 0.2862 - val_loss: 1.5822 - val_angle_error: 4.4004 - val_accuracy: 0.4877
# Epoch 6/50
# 211/214 [============================>.] - ETA: 0s - loss: 2.0414 - angle_error: 14.7453 - accuracy: 0.3158INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 2.0421 - angle_error: 14.7533 - accuracy: 0.3156 - val_loss: 1.4307 - val_angle_error: 5.3605 - val_accuracy: 0.5215
# Epoch 7/50
# 209/214 [============================>.] - ETA: 0s - loss: 1.9451 - angle_error: 13.5591 - accuracy: 0.3584INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.9439 - angle_error: 13.5915 - accuracy: 0.3575 - val_loss: 1.3540 - val_angle_error: 4.5181 - val_accuracy: 0.5312
# Epoch 8/50
# 214/214 [==============================] - ETA: 0s - loss: 1.8676 - angle_error: 12.5329 - accuracy: 0.3692INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.8676 - angle_error: 12.5329 - accuracy: 0.3692 - val_loss: 1.2865 - val_angle_error: 4.1641 - val_accuracy: 0.5586
# Epoch 9/50
# 214/214 [==============================] - ETA: 0s - loss: 1.7878 - angle_error: 12.3197 - accuracy: 0.3901INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.7878 - angle_error: 12.3197 - accuracy: 0.3901 - val_loss: 1.2463 - val_angle_error: 4.0806 - val_accuracy: 0.5898
# Epoch 10/50
# 209/214 [============================>.] - ETA: 0s - loss: 1.7204 - angle_error: 11.6885 - accuracy: 0.4099INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.7195 - angle_error: 11.6851 - accuracy: 0.4107 - val_loss: 1.1872 - val_angle_error: 3.7634 - val_accuracy: 0.6055
# Epoch 11/50
# 210/214 [============================>.] - ETA: 0s - loss: 1.6775 - angle_error: 10.7795 - accuracy: 0.4279INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.6773 - angle_error: 10.7609 - accuracy: 0.4277 - val_loss: 1.1486 - val_angle_error: 3.7581 - val_accuracy: 0.6077
# Epoch 12/50
# 210/214 [============================>.] - ETA: 0s - loss: 1.6195 - angle_error: 10.8041 - accuracy: 0.4489INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.6169 - angle_error: 10.7888 - accuracy: 0.4505 - val_loss: 1.1145 - val_angle_error: 3.5014 - val_accuracy: 0.6303
# Epoch 13/50
# 209/214 [============================>.] - ETA: 0s - loss: 1.5772 - angle_error: 10.6878 - accuracy: 0.4537INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.5778 - angle_error: 10.7042 - accuracy: 0.4539 - val_loss: 1.0603 - val_angle_error: 3.7665 - val_accuracy: 0.6512
# Epoch 14/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.5184 - angle_error: 10.1417 - accuracy: 0.4759 - val_loss: 1.0766 - val_angle_error: 3.8775 - val_accuracy: 0.6437
# Epoch 15/50
# 209/214 [============================>.] - ETA: 0s - loss: 1.4964 - angle_error: 9.7104 - accuracy: 0.4870INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 15ms/step - loss: 1.4959 - angle_error: 9.7019 - accuracy: 0.4876 - val_loss: 1.0249 - val_angle_error: 3.1013 - val_accuracy: 0.6518
# Epoch 16/50
# 212/214 [============================>.] - ETA: 0s - loss: 1.4433 - angle_error: 9.3665 - accuracy: 0.5040INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.4428 - angle_error: 9.4026 - accuracy: 0.5037 - val_loss: 0.9626 - val_angle_error: 3.2751 - val_accuracy: 0.6755
# Epoch 17/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.4233 - angle_error: 9.3767 - accuracy: 0.5090 - val_loss: 0.9693 - val_angle_error: 3.3117 - val_accuracy: 0.6616
# Epoch 18/50
# 212/214 [============================>.] - ETA: 0s - loss: 1.3996 - angle_error: 8.8064 - accuracy: 0.5136INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.4033 - angle_error: 8.7960 - accuracy: 0.5135 - val_loss: 0.9303 - val_angle_error: 3.2171 - val_accuracy: 0.6934
# Epoch 19/50
# 214/214 [==============================] - 3s 12ms/step - loss: 1.3818 - angle_error: 8.9395 - accuracy: 0.5222 - val_loss: 0.9323 - val_angle_error: 3.0636 - val_accuracy: 0.6864
# Epoch 20/50
# 212/214 [============================>.] - ETA: 0s - loss: 1.3776 - angle_error: 8.8541 - accuracy: 0.5351INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.3780 - angle_error: 8.8398 - accuracy: 0.5349 - val_loss: 0.8925 - val_angle_error: 3.1791 - val_accuracy: 0.6948
# Epoch 21/50
# 211/214 [============================>.] - ETA: 0s - loss: 1.3388 - angle_error: 8.5127 - accuracy: 0.5440INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.3407 - angle_error: 8.5307 - accuracy: 0.5440 - val_loss: 0.8810 - val_angle_error: 2.5123 - val_accuracy: 0.7020
# Epoch 22/50
# 213/214 [============================>.] - ETA: 0s - loss: 1.3338 - angle_error: 8.6933 - accuracy: 0.5456INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.3351 - angle_error: 8.6782 - accuracy: 0.5456 - val_loss: 0.8737 - val_angle_error: 2.5818 - val_accuracy: 0.7151
# Epoch 23/50
# 210/214 [============================>.] - ETA: 0s - loss: 1.3282 - angle_error: 8.7193 - accuracy: 0.5489INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 15ms/step - loss: 1.3251 - angle_error: 8.7073 - accuracy: 0.5496 - val_loss: 0.8556 - val_angle_error: 2.9400 - val_accuracy: 0.7034
# Epoch 24/50
# 212/214 [============================>.] - ETA: 0s - loss: 1.3124 - angle_error: 8.9044 - accuracy: 0.5437INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.3107 - angle_error: 8.8868 - accuracy: 0.5442 - val_loss: 0.8473 - val_angle_error: 2.8153 - val_accuracy: 0.7154
# Epoch 25/50
# 213/214 [============================>.] - ETA: 0s - loss: 1.2754 - angle_error: 8.5019 - accuracy: 0.5620INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2749 - angle_error: 8.4911 - accuracy: 0.5622 - val_loss: 0.8315 - val_angle_error: 3.0156 - val_accuracy: 0.7140
# Epoch 26/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.2701 - angle_error: 8.5873 - accuracy: 0.5677 - val_loss: 0.8552 - val_angle_error: 3.2288 - val_accuracy: 0.6981
# Epoch 27/50
# 214/214 [==============================] - ETA: 0s - loss: 1.2549 - angle_error: 8.0963 - accuracy: 0.5660INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2549 - angle_error: 8.0963 - accuracy: 0.5660 - val_loss: 0.8211 - val_angle_error: 3.0898 - val_accuracy: 0.7207
# Epoch 28/50
# 213/214 [============================>.] - ETA: 0s - loss: 1.2470 - angle_error: 8.1183 - accuracy: 0.5693INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2475 - angle_error: 8.1397 - accuracy: 0.5693 - val_loss: 0.7975 - val_angle_error: 2.9085 - val_accuracy: 0.7316
# Epoch 29/50
# 214/214 [==============================] - ETA: 0s - loss: 1.2242 - angle_error: 8.0272 - accuracy: 0.5811INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2242 - angle_error: 8.0272 - accuracy: 0.5811 - val_loss: 0.7958 - val_angle_error: 2.6261 - val_accuracy: 0.7235
# Epoch 30/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.2196 - angle_error: 7.9211 - accuracy: 0.5857 - val_loss: 0.8145 - val_angle_error: 2.7070 - val_accuracy: 0.7333
# Epoch 31/50
# 214/214 [==============================] - ETA: 0s - loss: 1.2051 - angle_error: 7.7248 - accuracy: 0.5852INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2051 - angle_error: 7.7248 - accuracy: 0.5852 - val_loss: 0.7950 - val_angle_error: 2.7335 - val_accuracy: 0.7305
# Epoch 32/50
# 211/214 [============================>.] - ETA: 0s - loss: 1.2173 - angle_error: 8.1335 - accuracy: 0.5799INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.2155 - angle_error: 8.1579 - accuracy: 0.5802 - val_loss: 0.7696 - val_angle_error: 2.6415 - val_accuracy: 0.7433
# Epoch 33/50
# 214/214 [==============================] - ETA: 0s - loss: 1.1702 - angle_error: 7.5226 - accuracy: 0.5990INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.1702 - angle_error: 7.5226 - accuracy: 0.5990 - val_loss: 0.7675 - val_angle_error: 2.5326 - val_accuracy: 0.7330
# Epoch 34/50
# 213/214 [============================>.] - ETA: 0s - loss: 1.1750 - angle_error: 7.4698 - accuracy: 0.5972INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.1745 - angle_error: 7.4705 - accuracy: 0.5974 - val_loss: 0.7504 - val_angle_error: 2.6560 - val_accuracy: 0.7405
# Epoch 35/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.1940 - angle_error: 7.7163 - accuracy: 0.5913 - val_loss: 0.7583 - val_angle_error: 2.4032 - val_accuracy: 0.7458
# Epoch 36/50
# 211/214 [============================>.] - ETA: 0s - loss: 1.1488 - angle_error: 7.4155 - accuracy: 0.6044INFO:tensorflow:Assets written to: rotnet/assets
# 214/214 [==============================] - 3s 14ms/step - loss: 1.1478 - angle_error: 7.4166 - accuracy: 0.6043 - val_loss: 0.7226 - val_angle_error: 2.5405 - val_accuracy: 0.7464
# Epoch 37/50
# 214/214 [==============================] - 3s 12ms/step - loss: 1.1690 - angle_error: 7.5134 - accuracy: 0.5994 - val_loss: 0.7426 - val_angle_error: 3.0405 - val_accuracy: 0.7517
# Epoch 38/50
# 214/214 [==============================] - 2s 11ms/step - loss: 1.1470 - angle_error: 7.3099 - accuracy: 0.6053 - val_loss: 0.7459 - val_angle_error: 2.8345 - val_accuracy: 0.7319

# %%
# Access accuracy from history
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Plot accuracy over epochs
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print(training_accuracy[-1])
print(validation_accuracy[-1])
# Out:
# 0.6052573919296265
# 0.7318638563156128

# %%
# randomly rotate an image
original_img = X_test[0]
rotation_angles = [0, 90, 180, 270]
true_angle = np.random.choice(rotation_angles)
rotated_img = rotate(original_img, true_angle)
print('True angle: ', true_angle)

# add dimensions to account for the batch size and channels, 
rotated_img = rotated_img[np.newaxis, :, :, np.newaxis]
# convert to float
rotated_img = rotated_img.astype('float32')
# binarize image
rotated_img_bin = binarize_images(rotated_img)

resized_rotated_img = resize(rotated_img_bin[0, :, :, 0], (28, 28))[np.newaxis, :, :, np.newaxis]

# predict rotation angle
output = model.predict(resized_rotated_img)
predicted_angle = np.argmax(output)
print('Predicted angle: ', predicted_angle)
# Out:
# True angle:  270
# Predicted angle:  271

# %%
original_img.shape
# Out:
# (28, 28)

# %%
num_images = 5

display_examples(
    model, 
    X_test,
    num_images=num_images,
    preprocess_func=binarize_images,
)

# %%
import numpy as np
from skimage.transform import resize
from skimage.color import rgb2gray
import tensorflow as tf

# %%
# Load your data
images_FML_df = pd.read_csv('data_train_compressed_gs.csv')

# %%
images_FML_df.shape
# Out:
# (8442, 784)

# %%
images_FML = images_FML_df.values.reshape(-1,28,28,1)

# %%
images_FML.shape
# Out:
# (8442, 28, 28, 1)

# %%
images_FML = np.squeeze(images_FML, axis=-1)

# %%
images_FML.shape
# Out:
# (8442, 28, 28)

# %%
# Plotting the first image from the loaded data
plt.imshow(images_FML[0], cmap='gray')
plt.axis('off')  # No axis for images
plt.show()

# %%
num_images = 100

display_examples(
    model, 
    images_FML,
    num_images=num_images,
    preprocess_func=binarize_images,
)

# %%
# randomly rotate an image
original_img = images_FML[2]
rotation_angles = [0]
true_angle = np.random.choice(rotation_angles)
rotated_img = rotate(original_img, true_angle)
print('True angle: ', true_angle)

# add dimensions to account for the batch size and channels, 
rotated_img = rotated_img[np.newaxis, :, :, np.newaxis]
# convert to float
rotated_img = rotated_img.astype('float32')
# binarize image
rotated_img_bin = binarize_images(rotated_img)

resized_rotated_img = resize(rotated_img_bin[0, :, :, 0], (28, 28))[np.newaxis, :, :, np.newaxis]

# predict rotation angle
output = model.predict(resized_rotated_img)
predicted_angle = np.argmax(output)
print('Predicted angle: ', predicted_angle)
# Out:
# True angle:  0
# Predicted angle:  357

# %%
# Plotting the first image from the loaded data
plt.imshow(images_FML[2], cmap='gray')
plt.axis('off')  # No axis for images
plt.show()
